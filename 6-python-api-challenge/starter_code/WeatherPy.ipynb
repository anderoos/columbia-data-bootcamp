# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats as st

# # Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Testing single query before making multiple requests
url = "https://api.openweathermap.org/data/2.5/weather?units=metric&q="
city_data = []
city_url = f"{url}{cities[0]}&appid={weather_api_key}"
# print(weather_api_key)
print(cities[0])
payload_test = requests.get(city_url).json()
city_lat = payload_test['coord']['lat']
city_lng = payload_test['coord']['lon']
city_max_temp = payload_test['main']['temp_max']
city_humidity = payload_test['main']['humidity']
city_clouds = payload_test['clouds']['all']
city_wind = payload_test['wind']
city_country = payload_test['sys']['country']
city_date = payload_test['dt']
# Append the City information into city_data list
city_data.append({"City": cities[0], 
                  "Lat": city_lat, 
                  "Lng": city_lng, 
                  "Max Temp": city_max_temp,
                  "Humidity": city_humidity,
                  "Cloudiness": city_clouds,
                  "Wind Speed": city_wind,
                  "Country": city_country,
                  "Date": city_date})
city_data
# Out:
# port-aux-francais
# [{'City': 'port-aux-francais',
#   'Lat': -49.35,
#   'Lng': 70.2167,
#   'Max Temp': 1.97,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': {'speed': 16.88, 'deg': 251, 'gust': 19.62},
#   'Country': 'TF',
#   'Date': 1695754669}]

# %%
# # Set the API base URL
# url = "https://api.openweathermap.org/data/2.5/weather?q="

# # Define an empty list to fetch the weather data for each city
# city_data = []

# # Print to logger
# print("Beginning Data Retrieval     ")
# print("-----------------------------")

# # Create counters
# record_count = 1
# set_count = 1

# # Loop through all the cities in our list to fetch weather data
# for i, city in enumerate(cities):
        
#     # Group cities in sets of 50 for logging purposes
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 0

#     # Create endpoint URL with each city
#     city_url = f"{url}{city}&appid={weather_api_key}"
#     print(city_url)
#     # Log the url, record, and set numbers
#     print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

#     # Add 1 to the record count
#     record_count += 1

#     # Run an API request for each of the cities
#     try:
#         # Parse the JSON and retrieve data
#         city_weather = requests.get(city_url).json()

#         # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
#         city_lat = city_weather['coord']['lat']
#         city_lng = city_weather['coord']['lon']
#         city_max_temp = city_weather['main']['temp_max']
#         city_humidity = city_weather['main']['humidity']
#         city_clouds = city_weather['clouds']
#         city_wind = city_weather['wind']
#         city_country = city_weather['sys']['country']
#         city_date = city_weather['dt']

#         # Append the City information into city_data list
#         city_data.append({"City": city, 
#                           "Lat": city_lat, 
#                           "Lng": city_lng, 
#                           "Max Temp": city_max_temp,
#                           "Humidity": city_humidity,
#                           "Cloudiness": city_clouds,
#                           "Wind Speed": city_wind,
#                           "Country": city_country,
#                           "Date": city_date})

#     # If an error is experienced, skip the city
#     except:
#         print("City not found. Skipping...")
#         continue
              
# # Indicate that Data Loading is complete 
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")

# %%
# Rewrote the code above for better exception handling. 
def city_data_retreival(cities_list):
    city_data = []
    url = "https://api.openweathermap.org/data/2.5/weather?units=metric&q="
    record_count = 1
    set_count = 1
    for i, city in enumerate(cities_list):
        city_url = f"{url}{city}&appid={weather_api_key}"
        print(city_url)
        response = requests.get(url)
        # Group cities in sets of 50 for logging purposes
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 0
        # Log the url, record, and set numbers
        print(f"Processing Record of {city}")
        # Add 1 to the record count
        record_count += 1
        response = requests.get(city_url)
        if response.status_code == 200:
            try:
                response = response.json()
                city_lat = response['coord']['lat']
                city_lng = response['coord']['lon']
                city_max_temp = response['main']['temp_max']
                city_humidity = response['main']['humidity']
                city_clouds = response['clouds']['all']
                city_wind = response['wind']['speed']
                city_country = response['sys']['country']
                city_date = response['dt']
                # Append the City information into city_data list
                city_data.append({"City": city, 
                                  "Lat": city_lat, 
                                  "Lng": city_lng, 
                                  "Max Temp": city_max_temp,
                                  "Humidity": city_humidity,
                                  "Cloudiness": city_clouds,
                                  "Wind Speed": city_wind,
                                  "Country": city_country,
                                  "Date": city_date})
            except NameError:
                print(f"Name not found.")
            except KeyError:
                print("Key not found")
            except Exception:
                print('We hit an exception that is not a NameError or TypeError!')
        elif response.status_code == 404:
            print(f'404 {city} not found')
            continue
        elif response.status_code == 400:
            print('400 Bad Request')
            break
    return city_data

# %%
# Data retreival 
city_weather_payload = city_data_retreival(cities)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=port-aux-francais&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of port-aux-francais
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mugumu&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mugumu
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=port mathurin&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of port mathurin
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ribeira grande&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ribeira grande
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=blackmans bay&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of blackmans bay
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=revda&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of revda
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=puerto rico&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of puerto rico
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=grytviken&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of grytviken
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=wailua homesteads&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of wailua homesteads
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=taiohae&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of taiohae
# 404 taiohae not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=okakarara&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of okakarara
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=adamstown&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of adamstown
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=paramirim&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of paramirim
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=cromwell&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of cromwell
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nova sintra&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nova sintra
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=iskateley&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of iskateley
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=trincomalee&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of trincomalee
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hamilton&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hamilton
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=yellowknife&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of yellowknife
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=labasa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of labasa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=turinskaya sloboda&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of turinskaya sloboda
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=matadi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of matadi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=anadyr&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of anadyr
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=badger&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of badger
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=broken hill&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of broken hill
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=yemva&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of yemva
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=stanley&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of stanley
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tazacorte&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tazacorte
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=aasiaat&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of aasiaat
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vlahita&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vlahita
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=puerto ayora&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of puerto ayora
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=waitangi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of waitangi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=chonchi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of chonchi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bethel&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bethel
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=olonkinbyen&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of olonkinbyen
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=carnarvon&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of carnarvon
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kabalo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kabalo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=oswego&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of oswego
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=zeya&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of zeya
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=enewetak&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of enewetak
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=cole harbour&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of cole harbour
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=flin flon&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of flin flon
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=brookings&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of brookings
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ancud&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ancud
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nuuk&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nuuk
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ushuaia&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ushuaia
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vorgashor&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vorgashor
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=muromtsevo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of muromtsevo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=cumaribo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of cumaribo
# 404 cumaribo not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=isafjordur&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of isafjordur
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hawaiian paradise park&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hawaiian paradise park
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kourou&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kourou
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=cabo san lucas&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of cabo san lucas
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mukalla&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mukalla
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ballina&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ballina
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ouesso&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ouesso
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=invercargill&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of invercargill
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=saint-pierre&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of saint-pierre
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=port lincoln&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of port lincoln
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=visakhapatnam&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of visakhapatnam
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hadibu&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hadibu
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=oamaru&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of oamaru
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=iron river&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of iron river
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=soio&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of soio
# https://api.openweathermap.org/data/2.5/weather?units=metric&q='ohonua&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of 'ohonua
# 404 'ohonua not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=trondheim&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of trondheim
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=west island&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of west island
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=touros&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of touros
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=south hedland&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of south hedland
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bilibino&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bilibino
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=port elizabeth&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of port elizabeth
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=uturoa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of uturoa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=rabigh&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of rabigh
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=jamestown&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of jamestown
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=haiku-pauwela&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of haiku-pauwela
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tagta&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tagta
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=udachny&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of udachny
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=margaret river&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of margaret river
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=colonia&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of colonia
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=remire-montjoly&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of remire-montjoly
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=afif&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of afif
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=burang&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of burang
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=medicine hat&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of medicine hat
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hammerfest&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hammerfest
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=longyearbyen&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of longyearbyen
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=naze&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of naze
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=novogrudok&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of novogrudok
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=fort mcmurray&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of fort mcmurray
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=albany&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of albany
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kingston&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kingston
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=isangel&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of isangel
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kinablangan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kinablangan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=puerto natales&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of puerto natales
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bichura&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bichura
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vilyuysk&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vilyuysk
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=luganville&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of luganville
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=novyy urgal&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of novyy urgal
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=la carolina&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of la carolina
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=yakeshi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of yakeshi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=san luis ixcan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of san luis ixcan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bandarbeyla&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bandarbeyla
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vernon&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vernon
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=jawf al maqbabah&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of jawf al maqbabah
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=roxas&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of roxas
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=arar&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of arar
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=airuk&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of airuk
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=muravlenko&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of muravlenko
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=illizi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of illizi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=yermakovskoye&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of yermakovskoye
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=papatowai&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of papatowai
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tranovaho&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tranovaho
# 404 tranovaho not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=umba&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of umba
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ust-nera&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ust-nera
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mcgregor&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mcgregor
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=qaqortoq&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of qaqortoq
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=caleta olivia&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of caleta olivia
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hirara&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hirara
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=gulariya&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of gulariya
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=edinburgh of the seven seas&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of edinburgh of the seven seas
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kerikeri&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kerikeri
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=punta arenas&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of punta arenas
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vaasa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vaasa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sisimiut&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sisimiut
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tiksi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tiksi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vadso&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vadso
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=al qadarif&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of al qadarif
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=constantia&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of constantia
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=szczecinek&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of szczecinek
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tazovsky&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tazovsky
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=eraan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of eraan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=dryden&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of dryden
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=howard springs&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of howard springs
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=leh&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of leh
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=cargados carajos&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of cargados carajos
# 404 cargados carajos not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nambucca&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nambucca
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ceerigaabo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ceerigaabo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tabas&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tabas
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sterling&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sterling
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=utrik&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of utrik
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=north bend&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of north bend
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=karratha&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of karratha
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mahabe&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mahabe
# 404 mahabe not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=zaragoza&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of zaragoza
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mitu&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mitu
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nar'yan-mar&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nar'yan-mar
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=gadzhiyevo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of gadzhiyevo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tolanaro&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tolanaro
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=beyneu&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of beyneu
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=atafu village&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of atafu village
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=smithers&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of smithers
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kupang&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kupang
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=barcelos&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of barcelos
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kotlas&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kotlas
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=porto novo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of porto novo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mhamid&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mhamid
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=dzuunharaa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of dzuunharaa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=loa janan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of loa janan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=coquimbo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of coquimbo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=yuzhno-kurilsk&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of yuzhno-kurilsk
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=koprubasi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of koprubasi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=harper&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of harper
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=rapar&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of rapar
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=igarka&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of igarka
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=natal&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of natal
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bikenibeu village&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bikenibeu village
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hermanus&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hermanus
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=egilsstadir&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of egilsstadir
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=codrington&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of codrington
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=iwon-up&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of iwon-up
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=whitehorse&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of whitehorse
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=papao&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of papao
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=saipan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of saipan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=villa ojo de agua&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of villa ojo de agua
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kapa'a&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kapa'a
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bredasdorp&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bredasdorp
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nemuro&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nemuro
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=westport&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of westport
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=daru&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of daru
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=pauini&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of pauini
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=oum hadjer&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of oum hadjer
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mil'kovo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mil'kovo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sechura&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sechura
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=avarua&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of avarua
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=suncho corral&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of suncho corral
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kendari&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kendari
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=dhidhdhoo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of dhidhdhoo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=college&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of college
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=puerto aysen&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of puerto aysen
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=khandud&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of khandud
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=manokwari&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of manokwari
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=marquette&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of marquette
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=altus&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of altus
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=cova figueira&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of cova figueira
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=iqaluit&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of iqaluit
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kaifeng&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kaifeng
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=petropavlovsk-kamchatsky&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of petropavlovsk-kamchatsky
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=malmberget&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of malmberget
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=yangambi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of yangambi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=otjiwarongo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of otjiwarongo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hotan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hotan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=severo-yeniseyskiy&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of severo-yeniseyskiy
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=newman&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of newman
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=weno&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of weno
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=al ghayzah&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of al ghayzah
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bukama&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bukama
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tamanrasset&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tamanrasset
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=settat&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of settat
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=st. john's&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of st. john's
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=el granada&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of el granada
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=susuman&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of susuman
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=concepcion&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of concepcion
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=port douglas&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of port douglas
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=usogorsk&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of usogorsk
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sinabang&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sinabang
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=khromtau&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of khromtau
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mount isa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mount isa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kodiak&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kodiak
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tondano&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tondano
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sitka&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sitka
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ilulissat&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ilulissat
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=beaudesert&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of beaudesert
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=aioun&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of aioun
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=itoman&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of itoman
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=coahuayana de hidalgo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of coahuayana de hidalgo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kayangel&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kayangel
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=siwa oasis&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of siwa oasis
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=guichon&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of guichon
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sogndal&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sogndal
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=puerto baquerizo moreno&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of puerto baquerizo moreno
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vilyuchinsk&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vilyuchinsk
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hithadhoo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hithadhoo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=priozersk&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of priozersk
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=udomlya&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of udomlya
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mount gambier&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mount gambier
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=basco&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of basco
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ocean city&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ocean city
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=banikoara&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of banikoara
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=salinas&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of salinas
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hengchun&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hengchun
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=auki&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of auki
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=port jervis&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of port jervis
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=pont rouge&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of pont rouge
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bratsk&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bratsk
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=pisco&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of pisco
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=acapulco de juarez&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of acapulco de juarez
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=selfoss&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of selfoss
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vuktyl&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vuktyl
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ulanhot&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ulanhot
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nogliki&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nogliki
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=drahichyn&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of drahichyn
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=khandyga&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of khandyga
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=orchard homes&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of orchard homes
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=xinyuan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of xinyuan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=le vauclin&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of le vauclin
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=afaahiti&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of afaahiti
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=christchurch&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of christchurch
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kiunga&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kiunga
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=cangucu&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of cangucu
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=as sulayyil&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of as sulayyil
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sirajganj&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sirajganj
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=chiroqchi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of chiroqchi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=martapura&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of martapura
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=northam&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of northam
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=gagliano del capo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of gagliano del capo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=aginskoye&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of aginskoye
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vila franca do campo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vila franca do campo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=motygino&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of motygino
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=necochea&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of necochea
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=changli&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of changli
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=miarinarivo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of miarinarivo
# 404 miarinarivo not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=parauapebas&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of parauapebas
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bouarfa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bouarfa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hofors&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hofors
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=taltal&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of taltal
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=beira&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of beira
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=thompson&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of thompson
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tokar&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tokar
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kenai&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kenai
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vila velha&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vila velha
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=dudinka&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of dudinka
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kailua-kona&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kailua-kona
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=niepolomice&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of niepolomice
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=cannonvale&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of cannonvale
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=lerwick&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of lerwick
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=abraham's bay&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of abraham's bay
# 404 abraham's bay not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=yanam&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of yanam
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kankan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kankan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=fortaleza&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of fortaleza
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=peace river&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of peace river
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=novovarshavka&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of novovarshavka
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=lebu&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of lebu
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mejit&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mejit
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=dire dawa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of dire dawa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ocean pointe&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ocean pointe
# 404 ocean pointe not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=carqueiranne&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of carqueiranne
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=zayed city&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of zayed city
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=coxim&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of coxim
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=arteaga&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of arteaga
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=velikiye luki&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of velikiye luki
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sungai penuh&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sungai penuh
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=klyuchi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of klyuchi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=port augusta&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of port augusta
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kavieng&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kavieng
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=castillos&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of castillos
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nema&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nema
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=la paz&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of la paz
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=aghajari&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of aghajari
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=casablanca&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of casablanca
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=quellon&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of quellon
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mpanda&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mpanda
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vail&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vail
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bouira&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bouira
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=minas de marcona&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of minas de marcona
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bayramaly&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bayramaly
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=moose jaw&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of moose jaw
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kangaba&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kangaba
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=yarega&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of yarega
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bridgewater&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bridgewater
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ifrane&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ifrane
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=aykhal&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of aykhal
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=douz&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of douz
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ta`u&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ta`u
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nafada&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nafada
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=chiredzi&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of chiredzi
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=montpelier&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of montpelier
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=meizhou&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of meizhou
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tumaco&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tumaco
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=keflavik&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of keflavik
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=fuvahmulah&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of fuvahmulah
# 404 fuvahmulah not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tuy hoa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tuy hoa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=pampa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of pampa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=timimoun&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of timimoun
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bereznik&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bereznik
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=dalandzadgad&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of dalandzadgad
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=pampa del indio&appid=36427b6e675f02987085f8545a5d72ce
# ...
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bulayevo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bulayevo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=svetlyy&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of svetlyy
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=rio grande&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of rio grande
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=pyu&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of pyu
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=pesqueira&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of pesqueira
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=rio gallegos&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of rio gallegos
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sault ste. marie&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sault ste. marie
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=krasnyy chikoy&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of krasnyy chikoy
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=xiaoshan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of xiaoshan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=shimoda&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of shimoda
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mgandu&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mgandu
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bodenwerder&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bodenwerder
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=khovd&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of khovd
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=white river&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of white river
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sandakan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sandakan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=muzayri'&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of muzayri'
# 404 muzayri' not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kalabo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kalabo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=al bukayriyah&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of al bukayriyah
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sumbe&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sumbe
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nili&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nili
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=songyang&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of songyang
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ambon&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ambon
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=warmbad&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of warmbad
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tindouf&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tindouf
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=san antonio de pale&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of san antonio de pale
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=dembi dolo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of dembi dolo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=la ronge&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of la ronge
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=alpena&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of alpena
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=argo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of argo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=pandan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of pandan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mumbwa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mumbwa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=zabaykal'sk&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of zabaykal'sk
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=patterson&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of patterson
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=berezovyy&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of berezovyy
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=miyaly&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of miyaly
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=thunder bay&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of thunder bay
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=greenbrier&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of greenbrier
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=wynyard&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of wynyard
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kidal&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kidal
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=oodweyne&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of oodweyne
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=taco pozo&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of taco pozo
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=quthing&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of quthing
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bargara&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bargara
# 404 bargara not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bazarnyye mataki&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bazarnyye mataki
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sinop&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sinop
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nova xavantina&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nova xavantina
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=akureyri&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of akureyri
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=biltine&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of biltine
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=pontianak&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of pontianak
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=dinghaicun&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of dinghaicun
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kifri&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kifri
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kaa-khem&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kaa-khem
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tanki leendert&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tanki leendert
# 404 tanki leendert not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=jindabyne&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of jindabyne
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=iquique&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of iquique
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=beya&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of beya
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=totness&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of totness
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=buala&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of buala
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=red hill&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of red hill
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=palasa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of palasa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=shangri-la&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of shangri-la
# 404 shangri-la not found
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kalmunai&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kalmunai
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=zyryanovsk&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of zyryanovsk
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=warrnambool&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of warrnambool
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bargaal&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bargaal
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=fougeres&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of fougeres
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=chegdomyn&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of chegdomyn
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=hell-ville&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of hell-ville
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=fale old settlement&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of fale old settlement
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=tofol&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of tofol
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=vila do maio&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of vila do maio
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=gebeit&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of gebeit
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=silver city&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of silver city
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kimbe&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kimbe
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=huntsville&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of huntsville
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sheksna&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sheksna
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=lospalos&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of lospalos
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=george town&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of george town
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ixtapa&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ixtapa
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kani keli&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kani keli
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=puerto deseado&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of puerto deseado
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=flying fish cove&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of flying fish cove
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=kolyvan'&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of kolyvan'
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=el aioun&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of el aioun
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=beypore&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of beypore
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=galliano&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of galliano
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=chui&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of chui
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sola&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sola
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=island harbour&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of island harbour
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=irituia&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of irituia
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=valdivia&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of valdivia
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=sorong&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of sorong
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=arvayheer&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of arvayheer
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=snyder&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of snyder
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=aripuana&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of aripuana
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=cockburn town&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of cockburn town
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=eynesil&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of eynesil
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=luderitz&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of luderitz
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=pacific grove&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of pacific grove
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=shache&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of shache
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=laibin&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of laibin
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=mariel&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of mariel
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=riachao&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of riachao
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=golere&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of golere
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=nouadhibou&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of nouadhibou
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=harstad&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of harstad
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=bel ombre&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of bel ombre
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=ha'il&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of ha'il
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=huanan&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of huanan
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=radyvyliv&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of radyvyliv
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=manistee&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of manistee
# https://api.openweathermap.org/data/2.5/weather?units=metric&q=dunedin&appid=36427b6e675f02987085f8545a5d72ce
# Processing Record of dunedin

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_weather_payload)

# Exporting to csv
city_data_df.to_csv("../output_data/city_weather.csv")

# %%
# Show Record Count
city_data_df = pd.read_csv("../output_data/city_weather.csv")
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  561 non-null    int64
#  1   City        561 non-null    object
#  2   Lat         561 non-null    float64
#  3   Lng         561 non-null    float64
#  4   Max Temp    561 non-null    float64
#  5   Humidity    561 non-null    int64
#  6   Cloudiness  561 non-null    int64
#  7   Wind Speed  561 non-null    float64
#  8   Country     557 non-null    object
#  9   Date        561 non-null    int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 44.0+ KB

# %%
# Display sample data
city_data_df.head()
# Out:
#    Unnamed: 0               City      Lat       Lng  Max Temp  Humidity  \
# 0           0  port-aux-francais -49.3500   70.2167      1.97        82
# 1           1             mugumu  -1.8500   34.7000     19.09        76
# 2           2      port mathurin -19.6833   63.4167     22.92        65
# 3           3     ribeira grande  38.5167  -28.7000     23.22        94
# 4           4      blackmans bay -43.0167  147.3167      5.85        91
#
#    Cloudiness  Wind Speed Country        Date
# 0          98       16.88      TF  1695754669
# 1          40        0.96      TZ  1695754670
# 2           2        9.37      MU  1695754435
# 3          40        8.23      PT  1695754418
# 4          80        1.94      AU  1695754056

# %%
# Export the City_Data into a csv
# city_data_df.to_csv("cities.csv", index_label="City_ID")

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
fig0, ax0 = plt.subplots()
ax0.scatter(x=city_data_df['Lat'], y=city_data_df['Max Temp'])
# Incorporate the other graph properties
ax0.set_xlabel("Latitude")
ax0.set_ylabel("Temperature °C")
ax0.set_title("Latitude versus Temperature in September 2023")
ax0.set_xlim(-90, 90)
ax0.set_ylim(-20, 60)
ax0.axvline(0, linestyle='dashed', color='red')
# Save the figure
plt.savefig("../output_data/Fig1.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
fig1, ax1 = plt.subplots()
ax1.scatter(x=city_data_df['Lat'], y=city_data_df['Humidity'])

# Incorporate the other graph properties
ax1.set_xlabel("Latitude")
ax1.set_ylabel("Humidity")
ax1.set_title("Latitude versus Humidity in September 2023")
ax1.set_xlim(-90, 90)
ax1.set_ylim(-5, 105)
ax1.axvline(0, linestyle='dashed', color='red')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
# plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
fig2, ax2 = plt.subplots()
ax2.scatter(x=city_data_df['Lat'], y=city_data_df['Cloudiness'])

# Incorporate the other graph properties
ax2.set_xlabel("Latitude")
ax2.set_ylabel("Cloudiness %")
ax2.set_title("Latitude versus Cloudiness in September 2023")
ax2.set_xlim(-90, 90)
ax2.set_ylim(-5, 105)
ax2.axvline(0, linestyle='dashed', color='red')

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
fig3, ax3 = plt.subplots()
ax3.scatter(x=city_data_df['Lat'], y=city_data_df['Wind Speed'])

# Incorporate the other graph properties
ax3.set_xlabel("Latitude")
ax3.set_ylabel("Windspeed m/s")
ax3.set_title("Latitude versus Windspeed in September 2023")
ax3.set_xlim(-90, 90)
ax3.set_ylim(-5, 20)
ax3.axvline(0, linestyle='dashed', color='red')

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# Slope, intercept, rval, pval, sterr, inter_stderr
def get_lin_regress(col1, col2):
    linreg_params = st.linregress(col1, col2)
    line = (linreg_params[0] * col1) + linreg_params[1]
    equation = f"y = {round(linreg_params[0], 2)}x + {round(linreg_params[1], 2)}"
    return linreg_params, line, equation

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] > 0].reset_index(drop=True)
# Display sample data
northern_hemi_df.head()
# Out:
#    Unnamed: 0               City      Lat       Lng  Max Temp  Humidity  \
# 0           3     ribeira grande  38.5167  -28.7000     23.22        94
# 1           5              revda  56.8010   59.9303      6.08        92
# 2           8  wailua homesteads  22.0669 -159.3780     26.53        72
# 3          12           cromwell  41.5951  -72.6454     18.58        74
# 4          13        nova sintra  14.8667  -24.7167     24.23        78
#
#    Cloudiness  Wind Speed Country        Date
# 0          40        8.23      PT  1695754418
# 1          17        2.02      RU  1695754670
# 2           0        8.23      US  1695754419
# 3         100        5.66      US  1695754556
# 4          98        4.28      CV  1695754672

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0].reset_index(drop=True)
# Display sample data
southern_hemi_df.head()
# Out:
#    Unnamed: 0               City      Lat       Lng  Max Temp  Humidity  \
# 0           0  port-aux-francais -49.3500   70.2167      1.97        82
# 1           1             mugumu  -1.8500   34.7000     19.09        76
# 2           2      port mathurin -19.6833   63.4167     22.92        65
# 3           4      blackmans bay -43.0167  147.3167      5.85        91
# 4           6        puerto rico -26.7960  -55.0240     39.38        23
#
#    Cloudiness  Wind Speed Country        Date
# 0          98       16.88      TF  1695754669
# 1          40        0.96      TZ  1695754670
# 2           2        9.37      MU  1695754435
# 3          80        1.94      AU  1695754056
# 4          26        3.78      AR  1695754671

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lat_vs_temp_reg_param_n, lat_vs_temp_reg_n, lat_vs_temp_eq_n = get_lin_regress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
fig4, ax4 = plt.subplots()
ax4.scatter(x=northern_hemi_df['Lat'], y=northern_hemi_df['Max Temp'])
ax4.plot(northern_hemi_df['Lat'], lat_vs_temp_reg_n, color='red', linestyle='solid', label=lat_vs_temp_eq_n)
# Incorporate the other graph properties
ax4.set_xlabel("Latitude")
ax4.set_ylabel("Temperature °C")
ax4.set_title("Latitude versus Temperature in September 2023")
ax4.set_xlim(-5, 90)
ax4.set_ylim(-20, 50)
ax4.axvline(0, linestyle='dashed', color='red')
ax4.legend(frameon=False, loc='best')
ax4.annotate(text=f"r= {round(lat_vs_temp_reg_param_n[0], 8)}", xy=(60,40))
# Save the figure
plt.savefig("../output_data/Fig5.png")
# Show plot
plt.show()

# %%
# Linear regression on Southern Hemisphere
lat_vs_temp_reg_param_s, lat_vs_temp_reg_s, lat_vs_temp_eq_s = get_lin_regress(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
fig5, ax5 = plt.subplots()
ax5.scatter(x=southern_hemi_df['Lat'], y=southern_hemi_df['Max Temp'])
ax5.plot(southern_hemi_df['Lat'], lat_vs_temp_reg_s, color='red', linestyle='solid', label=lat_vs_temp_eq_s)
# Incorporate the other graph properties
ax5.set_xlabel("Latitude")
ax5.set_ylabel("Temperature °C")
ax5.set_title("Latitude versus Temperature in September 2023")
ax5.set_xlim(-90, 5)
ax5.set_ylim(-20, 50)
ax5.axvline(0, linestyle='dashed', color='red')
ax5.legend(frameon=False, loc='best')
ax5.annotate(text=f"r= {round(lat_vs_temp_reg_param_s[0], 8)}", xy=(-80,40))
# Save the figure
plt.savefig("../output_data/Fig6.png")
# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:**
# - There appears to be a relationship between latitude and temperaure. And an inverse relationship between northern and southern hemispheres

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lat_vs_hum_reg_param_n, lat_vs_hum_reg_n, lat_vs_hum_eq_n = get_lin_regress(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
fig6, ax6 = plt.subplots()
ax6.scatter(x=northern_hemi_df['Lat'], y=northern_hemi_df['Humidity'])
ax6.plot(northern_hemi_df['Lat'], lat_vs_hum_reg_n, color='red', linestyle='solid', label=lat_vs_hum_eq_n)
# Incorporate the other graph properties
ax6.set_xlabel("Latitude")
ax6.set_ylabel("Humidity %")
ax6.set_title("Latitude versus Humidity in September 2023")
ax6.set_xlim(-5, 90)
ax6.set_ylim(-5, 105)
ax6.axvline(0, linestyle='dashed', color='red')
ax6.legend(frameon=False, loc='best')
ax6.annotate(text=f"r= {round(lat_vs_hum_reg_param_n[0], 8)}", xy=(60,10))
# Save the figure
plt.savefig("../output_data/Fig7.png")
# Show plot
plt.show()

# %%
# Southern Hemisphere
lat_vs_hum_reg_param_s, lat_vs_hum_reg_s, lat_vs_hum_eq_s = get_lin_regress(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
fig7, ax7 = plt.subplots()
ax7.scatter(x=southern_hemi_df['Lat'], y=southern_hemi_df['Humidity'])
ax7.plot(southern_hemi_df['Lat'], lat_vs_hum_reg_s, color='red', linestyle='solid', label=lat_vs_hum_eq_s)
# Incorporate the other graph properties
ax7.set_xlabel("Latitude")
ax7.set_ylabel("Humidity %")
ax7.set_title("Latitude versus Humidity in September 2023")
ax7.set_xlim(-90, 5)
ax7.set_ylim(-5, 105)
ax7.axvline(0, linestyle='dashed', color='red')
ax7.legend(frameon=False, loc='best')
ax7.annotate(text=f"r= {round(lat_vs_hum_reg_param_s[0], 8)}", xy=(-85,90))
# Save the figure
plt.savefig("../output_data/Fig8.png")
# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:**
# - There is little/ no relationship between Latitude and Humidity

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lat_vs_cloud_reg_param_n, lat_vs_cloud_reg_n, lat_vs_cloud_eq_n = get_lin_regress(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
fig8, ax8 = plt.subplots()
ax8.scatter(x=northern_hemi_df['Lat'], y=northern_hemi_df['Cloudiness'])
ax8.plot(northern_hemi_df['Lat'], lat_vs_cloud_reg_n, color='red', linestyle='solid', label=lat_vs_cloud_eq_n)
# Incorporate the other graph properties
ax8.set_xlabel("Latitude")
ax8.set_ylabel("Cloudiness %")
ax8.set_title("Latitude versus Cloudiness in September 2023")
ax8.set_xlim(-5, 90)
ax8.set_ylim(-5, 105)
ax8.axvline(0, linestyle='dashed', color='red')
ax8.legend(frameon=False, loc='best')
ax8.annotate(text=f"r= {round(lat_vs_cloud_reg_param_n[0], 8)}", xy=(65,45))
# Save the figure
plt.savefig("../output_data/Fig9.png")
# Show plot
plt.show()

# %%
# Southern Hemisphere
lat_vs_cloud_reg_param_s, lat_vs_cloud_reg_s, lat_vs_cloud_eq_s = get_lin_regress(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
fig9, ax9 = plt.subplots()
ax9.scatter(x=southern_hemi_df['Lat'], y=southern_hemi_df['Cloudiness'])
ax9.plot(southern_hemi_df['Lat'], lat_vs_cloud_reg_s, color='red', linestyle='solid', label=lat_vs_cloud_eq_s)
# Incorporate the other graph properties
ax9.set_xlabel("Latitude")
ax9.set_ylabel("Cloudiness %")
ax9.set_title("Latitude versus Cloudiness in September 2023")
ax9.set_xlim(-90, 5)
ax9.set_ylim(-5, 105)
ax9.axvline(0, linestyle='dashed', color='red')
ax9.legend(frameon=False, loc='best')
ax9.annotate(text=f"r= {round(lat_vs_cloud_reg_param_s[0], 8)}", xy=(-85,90))
# Save the figure
plt.savefig("../output_data/Fig10.png")
# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:**
# - There is no/weak correlation between Latitude and cloudiness

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lat_vs_wind_reg_param_n, lat_vs_wind_reg_n, lat_vs_wind_eq_n = get_lin_regress(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
fig10, ax10 = plt.subplots()
ax10.scatter(x=northern_hemi_df['Lat'], y=northern_hemi_df['Wind Speed'])
ax10.plot(northern_hemi_df['Lat'], lat_vs_wind_reg_n, color='red', linestyle='solid', label=lat_vs_wind_eq_n)
# Incorporate the other graph properties
ax10.set_xlabel("Latitude")
ax10.set_ylabel("Wind Speed m/s")
ax10.set_title("Latitude versus Wind Speed in September 2023")
ax10.set_xlim(-5, 90)
ax10.set_ylim(-5, 20)
ax10.axvline(0, linestyle='dashed', color='red')
ax10.legend(frameon=False, loc='best')
ax10.annotate(text=f"r= {round(lat_vs_wind_reg_param_n[0], 8)}", xy=(65, 17))
# Save the figure
plt.savefig("../output_data/Fig11.png")
# Show plot
plt.show()

# %%
# Southern Hemisphere
lat_vs_wind_reg_param_s, lat_vs_wind_reg_s, lat_vs_wind_eq_s = get_lin_regress(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
fig11, ax11 = plt.subplots()
ax11.scatter(x=southern_hemi_df['Lat'], y=southern_hemi_df['Wind Speed'])
ax11.plot(southern_hemi_df['Lat'], lat_vs_wind_reg_s, color='red', linestyle='solid', label=lat_vs_wind_eq_s)
# Incorporate the other graph properties
ax11.set_xlabel("Latitude")
ax11.set_ylabel("Wind Speed m/s")
ax11.set_title("Latitude versus Wind Speed in September 2023")
ax11.set_xlim(-90, 5)
ax11.set_ylim(-5, 20)
ax11.axvline(0, linestyle='dashed', color='red')
ax11.legend(frameon=False, loc='best')
ax11.annotate(text=f"r= {round(lat_vs_wind_reg_param_s[0], 8)}", xy=(-85, 17))
# Save the figure
plt.savefig("../output_data/Fig12.png")
# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:**
# - There is a weak/ no correlation between Latitude and humidity
